# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread("./rick.png")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[0.14901961, 0.17254902, 0.22745098, 1.        ],
#         [0.14901961, 0.17254902, 0.22745098, 1.        ],
#         [0.14901961, 0.17254902, 0.22745098, 1.        ],
#         ...,
#         [0.14901961, 0.17254902, 0.22745098, 1.        ],
#         [0.14901961, 0.17254902, 0.22745098, 1.        ],
#         [0.14901961, 0.17254902, 0.22745098, 1.        ]],
#
#        [[0.14901961, 0.17254902, 0.22745098, 1.        ],
#         [0.14901961, 0.17254902, 0.22745098, 1.        ],
#         [0.14901961, 0.17254902, 0.22745098, 1.        ],
#         ...,
#         [0.14901961, 0.17254902, 0.22745098, 1.        ],
#         [0.14901961, 0.17254902, 0.22745098, 1.        ],
#         [0.14901961, 0.17254902, 0.22745098, 1.        ]],
#
#        [[0.14901961, 0.17254902, 0.22745098, 1.        ],
#         [0.14901961, 0.17254902, 0.22745098, 1.        ],
#         [0.14901961, 0.17254902, 0.22745098, 1.        ],
#         ...,
# ...

# %%
img.shape
# Out:
# (1080, 1920, 4)

# %%
# 4(Last part) is channel !

# %%
plt.imshow(img)

# %%
# img[rows, col, channel] for cropping

# %%
rick_face = img[100:900 , 1250:1750 , :]

# %%
plt.imshow(rick_face)
